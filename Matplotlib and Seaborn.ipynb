# %% [markdown]
# # <u>Matplotlib</u>
#
#
# Matplotlib supports essentially all 2D plot types (see matplotlib Gallery
# http://matplotlib.org/ or https://matplotlib.org/stable/tutorials/pyplot.html)

# %% [markdown]
# # <u>Seaborn</u>
