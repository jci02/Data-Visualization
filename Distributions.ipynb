# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
iris_data = pd.read_csv("iris.csv",index_col="Id")
iris_data
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.histplot(iris_data["Petal Length (cm)"])
plt.show()

#help(sns.kdeplot)
sns.kdeplot(iris_data["Petal Length (cm)"],fill=True)
plt.show()

# %%
sns.jointplot(data=iris_data,x="Petal Length (cm)",y="Sepal Width (cm)",kind="kde")
plt.show()

# %%
sns.histplot(data=iris_data,x="Petal Length (cm)",hue="Species")
plt.title("Histogram of Peta Lenghts by Species")
plt.show()



sns.kdeplot(data=iris_data,x="Petal Length (cm)",hue="Species",fill=True)
plt.title("Distribution of Peta Lenghts by Species")
plt.show()

# %%
cancer_data=pd.read_csv("cancer.csv",index_col="Id")
cancer_data
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
# ...            ...            ...             ...               ...
# 926125           M         20.920           25.09            143.00
# 926424           M         21.560           22.39            142.00
# 926682           M         20.130           28.25            131.20
# 926954           M         16.600           28.08            108.30
# 927241           M         20.600           29.33            140.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# ...

# %%
print("Radius of id 8510653 is",cancer_data.loc[8510653,"Radius (mean)"])
cancer_data.loc[8510653]
# Out:
# Radius of id 8510653 is 13.08
# Diagnosis                           B
# Radius (mean)                   13.08
# Texture (mean)                  15.71
# Perimeter (mean)                85.63
# Area (mean)                     520.0
# Smoothness (mean)              0.1075
# Compactness (mean)              0.127
# Concavity (mean)              0.04568
# Concave points (mean)          0.0311
# Symmetry (mean)                0.1967
# Fractal dimension (mean)      0.06811
# Radius (se)                    0.1852
# Texture (se)                   0.7477
# Perimeter (se)                  1.383
# Area (se)                       14.67
# Smoothness (se)              0.004097
# Compactness (se)              0.01898
# Concavity (se)                0.01698
# Concave points (se)           0.00649
# Symmetry (se)                 0.01678
# Fractal dimension (se)       0.002425
# Radius (worst)                   14.5
# Texture (worst)                 20.49
# Perimeter (worst)               96.09
# ...

# %%
sns.histplot(data=cancer_data,x="Area (mean)",hue="Diagnosis")
plt.title("Distribution of Area by Diagnosis")
plt.show()


sns.kdeplot(data=cancer_data,x="Area (mean)",hue="Diagnosis",fill=True)
plt.title("Distribution of Area by Diagnosis")
plt.show()
