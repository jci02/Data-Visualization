# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
spotify_data = pd.read_csv("spotify.csv")
spotify_data.head()
print(spotify_data["Date"].dtype)
spotify_data.info()
# Out:
# object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      366 non-null    object
#  1   Shape of You              366 non-null    int64
#  2   Despacito                 359 non-null    float64
#  3   Something Just Like This  319 non-null    float64
#  4   HUMBLE.                   282 non-null    float64
#  5   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
spotify_data = pd.read_csv("spotify.csv",parse_dates=["Date"])
spotify_data.head()
print(spotify_data["Date"].dtype)
spotify_data.info()
# Out:
# datetime64[ns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      366 non-null    datetime64[ns]
#  1   Shape of You              366 non-null    int64
#  2   Despacito                 359 non-null    float64
#  3   Something Just Like This  319 non-null    float64
#  4   HUMBLE.                   282 non-null    float64
#  5   Unforgettable             275 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 17.3 KB
